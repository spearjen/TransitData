# %%
import pandas as pd

df = pd.read_excel (r'TS1.1 Total Funding Time-Series.xlsx', sheet_name='Total')
df.head()
# Out:
#    Last Report Year  NTD ID Legacy NTD ID  \
# 0              2019     1.0             1
# 1              2019     2.0             2
# 2              2019     3.0             3
# 3              2019     4.0          0T04
# 4              2019     5.0             5
#
#                                          Agency Name Agency Status  \
# 0      King County Department of Metro Transit (KCM)        Active
# 1                    Spokane Transit Authority (STA)        Active
# 2  Pierce County Transportation Benefit Area Auth...        Active
# 3  Confederated Tribes of the Colville Indian Res...        Active
# 4                               City of Everett (ET)        Active
#
#       Reporter Type Reporting Module      City State  Census Year  ...  \
# 0     Full Reporter            Urban   Seattle    WA         2010  ...
# 1     Full Reporter            Urban   Spokane    WA         2010  ...
# 2     Full Reporter            Urban    Tacoma    WA         2010  ...
# ...

# %%
df_columns_filtered = df[['Agency Name', 'Agency Status', 'Reporting Module', 'City', 'State', '2001', '2002', 
                        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
                        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019' ]]

# %%
df_index = df_columns_filtered.set_index('Agency Name')
df_index
# Out:
#                                                    Agency Status  \
# Agency Name
# King County Department of Metro Transit (KCM)             Active
# Spokane Transit Authority (STA)                           Active
# Pierce County Transportation Benefit Area Autho...        Active
# Confederated Tribes of the Colville Indian Rese...        Active
# City of Everett (ET)                                      Active
# ...                                                          ...
# Indian Health Council, Inc                              Inactive
# Duckwater Shoshone Tribe                                Inactive
# Washoe Tribe of Nevada and California                   Inactive
# PEOPLE FOR PEOPLE                                       Inactive
# Eastern Sierra Transit Authority                        Inactive
#
#                                                    Reporting Module      City  \
# Agency Name
# King County Department of Metro Transit (KCM)                 Urban   Seattle
# ...

# %%
filter_to_active = df_index.loc[df_index['Agency Status']=='Active']
filter_to_active
# Out:
#                                                    Agency Status  \
# Agency Name
# King County Department of Metro Transit (KCM)             Active
# Spokane Transit Authority (STA)                           Active
# Pierce County Transportation Benefit Area Autho...        Active
# Confederated Tribes of the Colville Indian Rese...        Active
# City of Everett (ET)                                      Active
# ...                                                          ...
# Gila River Indian Community                               Active
# Town of Quartzsite                                        Active
# Payson Senior Center                                      Active
# Calaveras Transit Agency                                  Active
# Elk Valley Rancheria (EVR)                                Active
#
#                                                    Reporting Module  \
# Agency Name
# King County Department of Metro Transit (KCM)                 Urban
# ...

# %%
df_transposed = filter_to_active.T

# %%
df_transposed
# Out:
# Agency Name      King County Department of Metro Transit (KCM)  \
# Agency Status                                           Active
# Reporting Module                                         Urban
# City                                                   Seattle
# State                                                       WA
# 2001                                               4.00536e+08
# 2002                                               4.93524e+08
# 2003                                               5.06818e+08
# 2004                                               6.51927e+08
# 2005                                               5.09808e+08
# 2006                                               5.35031e+08
# 2007                                               5.72784e+08
# 2008                                               6.51636e+08
# 2009                                               6.68647e+08
# 2010                                               6.69733e+08
# ...
